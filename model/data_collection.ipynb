# %%
# !pip3 install pandas datasets numpy matplotlib seaborn huggingface_hub python-dotenv
# Out:
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/zade/Test/slangGPT/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset
from huggingface_hub import login
from dotenv import load_dotenv
import os

# %%
load_dotenv() 
HF_TOKEN = os.getenv("HF_TOKEN")
login(HF_TOKEN)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
df = load_dataset("wikimedia/wikipedia", "20231101.en")

# %%
train_ds = df["train"]
df_sm = train_ds.select(range(0, 1000000))

# %%
df_pandas = df_sm.to_pandas()

# %%
df_pandas
# Out:
#               id                                                url  \
# 0             12            https://en.wikipedia.org/wiki/Anarchism
# 1             39               https://en.wikipedia.org/wiki/Albedo
# 2            290                    https://en.wikipedia.org/wiki/A
# 3            303              https://en.wikipedia.org/wiki/Alabama
# 4            305             https://en.wikipedia.org/wiki/Achilles
# ...          ...                                                ...
# 999995  13922168  https://en.wikipedia.org/wiki/Special%20Delive...
# 999996  13922182  https://en.wikipedia.org/wiki/Peter%20Morris%2...
# 999997  13922206       https://en.wikipedia.org/wiki/Ian%20Clarkson
# 999998  13922209  https://en.wikipedia.org/wiki/The%20Uniques%20...
# 999999  13922213  https://en.wikipedia.org/wiki/List%20of%20news...
#
#                                   title  \
# 0                             Anarchism
# 1                                Albedo
# ...

# %%
df_pandas.to_csv("dataset/wikipedia_1M_1.csv", index=False)
